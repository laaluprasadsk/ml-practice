# %% [markdown]
# <a href="https://colab.research.google.com/github/laaluprasadsk/ml-practice/blob/main/iris_dataset_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

iris = load_iris()
x = iris.data
y = iris.target
pipe = Pipeline([
    ("scale", StandardScaler()),
    ("model", LinearRegression())
])
pipe.fit(x,y)
pred = mod.predict(x)
print("predicted",pred[:5])
print("actual",y[:5])
plt.scatter(pred,y)
# Out:
# predicted [-0.08254936 -0.04012845 -0.04862768  0.01229986 -0.07536672]
# actual [0 0 0 0 0]

# %%
pipe.fit(x,y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3930363644.py in <cell line: 0>()
# ----> 1 pipe.fit(x,y)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1387                 )
#    1388             ):
# -> 1389                 return fit_method(estimator, *args, **kwargs)
#    1390
#    1391         return wrapper
#
# /usr/local/lib/python3.12/dist-packages/sklearn/pipeline.py in fit(self, X, y, **params)
#     652
#     653         routed_params = self._check_method_params(method="fit", props=params)
# --> 654         Xt = self._fit(X, y, routed_params, raw_params=params)
#     655         with _print_elapsed_time("Pipeline", self._log_message(len(self.steps) - 1)):
#     656             if self._final_estimator != "passthrough":
#
# /usr/local/lib/python3.12/dist-packages/sklearn/pipeline.py in _fit(self, X, y, routed_params, raw_params)
#     560         # shallow copy of steps - this should really be steps_
#     561         self.steps = list(self.steps)
# --> 562         self._validate_steps()
#     563         # Setup the memory
#     564         memory = check_memory(self.memory)
#
# /usr/local/lib/python3.12/dist-packages/sklearn/pipeline.py in _validate_steps(self)
#     337                 t, "transform"
#     338             ):
# --> 339                 raise TypeError(
#     340                     "All intermediate steps should be "
#     341                     "transformers and implement fit and transform "
#
# TypeError: All intermediate steps should be transformers and implement fit and transform or be the string 'passthrough' 'LinearRegression()' (type <class 'sklearn.linear_model._base.LinearRegression'>) doesn't

# %%
import matplotlib.pyplot as plt
pred = mod.predict(x)
plt.scatter(pred ,y)
